# %%
import networkx as nx

from hc_embedding import hce

# %%
G = nx.powerlaw_cluster_graph(100, 2, 0.002)

# %%
hce_pos = hce.hc_embedding(G)
# Out:
# Calculating best minimal value for power law fit
# /Users/yyahn/.pyenv/versions/3.7.2/lib/python3.7/site-packages/powerlaw.py:700: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))

# %%
nx.draw(G, pos=hce_pos)
# Out:
# /Users/yyahn/.pyenv/versions/3.7.2/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
